# %%
import json
import yaml
import requests
import folium
with open("config.yaml", "r") as f:
    config = yaml.safe_load(f)

# %%
API_key =  config['API_key']
lat = 19.295867896783285
lon = -97.76888973800806
url = f'https://api.openweathermap.org/data/2.5/weather?lat={lat}&lon={lon}&appid={API_key}&units=metric'

# %%
response = requests.get(url)
data_weather = response.json()
data_weather
# Out:
# {'coord': {'lon': -97.7689, 'lat': 19.2959},
#  'weather': [{'id': 800,
#    'main': 'Clear',
#    'description': 'clear sky',
#    'icon': '01d'}],
#  'base': 'stations',
#  'main': {'temp': 22.18,
#   'feels_like': 20.77,
#   'temp_min': 22.18,
#   'temp_max': 22.18,
#   'pressure': 1017,
#   'humidity': 12,
#   'sea_level': 1017,
#   'grnd_level': 771},
#  'visibility': 10000,
#  'wind': {'speed': 1.18, 'deg': 320, 'gust': 2.41},
#  'clouds': {'all': 0},
#  'dt': 1708622728,
#  'sys': {'country': 'MX', 'sunrise': 1708606548, 'sunset': 1708648427},
#  'timezone': -21600,
#  'id': 3530033,
#  'name': 'Cuapiaxtla',
#  'cod': 200}

# %%
weather_description = data_weather['weather'][0]['description']
temp = data_weather['main']['temp']
text_pupup = f"Clima: {weather_description} <br>Temperatura: {temp} °C"

# %%
mapa = folium.Map(location=(lat, lon))
folium.Marker(
    location=[lat, lon],
    tooltip= 'Click Here',
    popup  = text_pupup,
    icon  =folium.Icon('cloud')
).add_to(mapa)

mapa
# Out:
# /tmp/ipykernel_148346/168895962.py:6: UserWarning: color argument of Icon should be one of: {'orange', 'pink', 'cadetblue', 'red', 'darkred', 'beige', 'blue', 'white', 'darkblue', 'darkgreen', 'lightgray', 'black', 'gray', 'darkpurple', 'lightred', 'purple', 'lightgreen', 'green', 'lightblue'}.
#   icon  =folium.Icon('cloud')
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_342a5a485a4842e8ef73f82ca9d2142c {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_342a5a485a4842e8ef73f82ca9d2142c&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_342a5a485a4842e8ef73f82ca9d2142c = L.map(
#                 &quot;map_342a5a485a4842e8ef73f82ca9d2142c&quot;,
#                 {
#                     center: [19.295867896783285, -97.76888973800806],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 10,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_45848e4ea8384e4f6ae6cda8645c515c = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 19, &quot;maxZoom&quot;: 19, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_45848e4ea8384e4f6ae6cda8645c515c.addTo(map_342a5a485a4842e8ef73f82ca9d2142c);
#
#
#             var marker_ef6639ed73850633f5c24d02cdfbc921 = L.marker(
#                 [19.295867896783285, -97.76888973800806],
#                 {}
#             ).addTo(map_342a5a485a4842e8ef73f82ca9d2142c);
#
#
#             var icon_2d54d21a036c83333b8175f5a46b2de8 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;cloud&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_ef6639ed73850633f5c24d02cdfbc921.setIcon(icon_2d54d21a036c83333b8175f5a46b2de8);
#
#
#         var popup_2ef8ff3b26e46efcc6062b7a257b74c2 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_b8e0fbb02c399f7266dd0709b416e0b9 = $(`&lt;div id=&quot;html_b8e0fbb02c399f7266dd0709b416e0b9&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Clima: clear sky &lt;br&gt;Temperatura: 22.18 °C&lt;/div&gt;`)[0];
#                 popup_2ef8ff3b26e46efcc6062b7a257b74c2.setContent(html_b8e0fbb02c399f7266dd0709b416e0b9);
#
#
#
#         marker_ef6639ed73850633f5c24d02cdfbc921.bindPopup(popup_2ef8ff3b26e46efcc6062b7a257b74c2)
#         ;
#
#
#
#
#             marker_ef6639ed73850633f5c24d02cdfbc921.bindTooltip(
#                 `&lt;div&gt;
#                      Click Here
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
# &lt;/script&gt;
# &lt;/html&gt;" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
mapa
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_342a5a485a4842e8ef73f82ca9d2142c {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_342a5a485a4842e8ef73f82ca9d2142c&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_342a5a485a4842e8ef73f82ca9d2142c = L.map(
#                 &quot;map_342a5a485a4842e8ef73f82ca9d2142c&quot;,
#                 {
#                     center: [19.295867896783285, -97.76888973800806],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 10,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_45848e4ea8384e4f6ae6cda8645c515c = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 19, &quot;maxZoom&quot;: 19, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_45848e4ea8384e4f6ae6cda8645c515c.addTo(map_342a5a485a4842e8ef73f82ca9d2142c);
#
#
#             var marker_ef6639ed73850633f5c24d02cdfbc921 = L.marker(
#                 [19.295867896783285, -97.76888973800806],
#                 {}
#             ).addTo(map_342a5a485a4842e8ef73f82ca9d2142c);
#
#
#             var icon_2d54d21a036c83333b8175f5a46b2de8 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;cloud&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_ef6639ed73850633f5c24d02cdfbc921.setIcon(icon_2d54d21a036c83333b8175f5a46b2de8);
#
#
#         var popup_2ef8ff3b26e46efcc6062b7a257b74c2 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_b8e0fbb02c399f7266dd0709b416e0b9 = $(`&lt;div id=&quot;html_b8e0fbb02c399f7266dd0709b416e0b9&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Clima: clear sky &lt;br&gt;Temperatura: 22.18 °C&lt;/div&gt;`)[0];
#                 popup_2ef8ff3b26e46efcc6062b7a257b74c2.setContent(html_b8e0fbb02c399f7266dd0709b416e0b9);
#
#
#
#         marker_ef6639ed73850633f5c24d02cdfbc921.bindPopup(popup_2ef8ff3b26e46efcc6062b7a257b74c2)
#         ;
#
#
#
#
#             marker_ef6639ed73850633f5c24d02cdfbc921.bindTooltip(
#                 `&lt;div&gt;
#                      Click Here
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             tile_layer_45848e4ea8384e4f6ae6cda8645c515c.addTo(map_342a5a485a4842e8ef73f82ca9d2142c);
#
# &lt;/script&gt;
# &lt;/html&gt;" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# ## Ejemplo con 3 ciudades

# %%
mapa_invernaderos = folium.Map(location=(lat, lon))

# %%
cities = config['cities']
for city, coord in cities.items():
    lat = coord[0]
    lon = coord[1]

    url = f'https://api.openweathermap.org/data/2.5/weather?lat={lat}&lon={lon}&appid={API_key}&units=metric'
    response = requests.get(url)
    date_weather = response.json()
    print(date_weather)
    weather_description = data_weather['weather'][0]['description']
    temp = data_weather['main']['temp']
    name = data_weather['name']

    text_pupup = f"El clima en {name} es. Clima: {weather_description} <br>Temperatura: {temp} °C"

    folium.Marker(
        location=[lat, lon],
        tooltip= name,
        popup  = text_pupup,
        icon  =folium.Icon('cloud')
    ).add_to(mapa_invernaderos)
# Out:
# Atlixco 18.923085025419557 -98.39557636380162
# {'coord': {'lon': -98.3956, 'lat': 18.9231}, 'weather': [{'id': 800, 'main': 'Clear', 'description': 'clear sky', 'icon': '01d'}], 'base': 'stations', 'main': {'temp': 26.32, 'feels_like': 26.32, 'temp_min': 26.32, 'temp_max': 26.32, 'pressure': 1016, 'humidity': 14, 'sea_level': 1016, 'grnd_level': 822}, 'visibility': 10000, 'wind': {'speed': 1.87, 'deg': 183, 'gust': 2.94}, 'clouds': {'all': 0}, 'dt': 1708623363, 'sys': {'country': 'MX', 'sunrise': 1708606681, 'sunset': 1708648595}, 'timezone': -21600, 'id': 3532592, 'name': 'Atlixco', 'cod': 200}
# El clima en Cuapiaxtla es. Clima: clear sky <br>Temperatura: 22.18 °C
# Cuapiaxtla 19.295867896783285 -97.76888973800806
# /tmp/ipykernel_148346/1137122924.py:21: UserWarning: color argument of Icon should be one of: {'orange', 'pink', 'cadetblue', 'red', 'darkred', 'beige', 'blue', 'white', 'darkblue', 'darkgreen', 'lightgray', 'black', 'gray', 'darkpurple', 'lightred', 'purple', 'lightgreen', 'green', 'lightblue'}.
#   icon  =folium.Icon('cloud')
# {'coord': {'lon': -97.7689, 'lat': 19.2959}, 'weather': [{'id': 800, 'main': 'Clear', 'description': 'clear sky', 'icon': '01d'}], 'base': 'stations', 'main': {'temp': 24.07, 'feels_like': 22.79, 'temp_min': 24.07, 'temp_max': 24.07, 'pressure': 1015, 'humidity': 10, 'sea_level': 1015, 'grnd_level': 771}, 'visibility': 10000, 'wind': {'speed': 1.43, 'deg': 343, 'gust': 2.4}, 'clouds': {'all': 0}, 'dt': 1708623364, 'sys': {'country': 'MX', 'sunrise': 1708606548, 'sunset': 1708648427}, 'timezone': -21600, 'id': 3530033, 'name': 'Cuapiaxtla', 'cod': 200}
# El clima en Cuapiaxtla es. Clima: clear sky <br>Temperatura: 22.18 °C
# Tehuacan 18.52639736316348 -97.47871399384229
# {'coord': {'lon': -97.4787, 'lat': 18.5264}, 'weather': [{'id': 800, 'main': 'Clear', 'description': 'clear sky', 'icon': '01d'}], 'base': 'stations', 'main': {'temp': 27.69, 'feels_like': 26.38, 'temp_min': 27.69, 'temp_max': 27.69, 'pressure': 1015, 'humidity': 11, 'sea_level': 1015, 'grnd_level': 837}, 'visibility': 10000, 'wind': {'speed': 2.36, 'deg': 261, 'gust': 2.52}, 'clouds': {'all': 0}, 'dt': 1708623364, 'sys': {'country': 'MX', 'sunrise': 1708606442, 'sunset': 1708648394}, 'timezone': -21600, 'id': 3523756, 'name': 'Magdalena Cuayucatepec', 'cod': 200}
# El clima en Cuapiaxtla es. Clima: clear sky <br>Temperatura: 22.18 °C
# Phoenix 33.39119277195364 -112.5928040604769
# {'coord': {'lon': -112.5928, 'lat': 33.3912}, 'weather': [{'id': 801, 'main': 'Clouds', 'description': 'few clouds', 'icon': '02d'}], 'base': 'stations', 'main': {'temp': 18.78, 'feels_like': 17.91, 'temp_min': 16.99, 'temp_max': 20.8, 'pressure': 1021, 'humidity': 46, 'sea_level': 1021, 'grnd_level': 988}, 'visibility': 10000, 'wind': {'speed': 1.42, 'deg': 2, 'gust': 1.93}, 'clouds': {'all': 18}, 'dt': 1708623365, 'sys': {'type': 2, 'id': 2046666, 'country': 'US', 'sunrise': 1708610850, 'sunset': 1708651240}, 'timezone': -25200, 'id': 5287262, 'name': 'Buckeye', 'cod': 200}
# El clima en Cuapiaxtla es. Clima: clear sky <br>Temperatura: 22.18 °C

# %%
mapa_invernaderos
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_f0cffe8ad9eeb53d991aaa603eb60f33 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_f0cffe8ad9eeb53d991aaa603eb60f33&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_f0cffe8ad9eeb53d991aaa603eb60f33 = L.map(
#                 &quot;map_f0cffe8ad9eeb53d991aaa603eb60f33&quot;,
#                 {
#                     center: [19.295867896783285, -97.76888973800806],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 10,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_47eed7bb516b0dab009c8e21d4f016f6 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 19, &quot;maxZoom&quot;: 19, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_47eed7bb516b0dab009c8e21d4f016f6.addTo(map_f0cffe8ad9eeb53d991aaa603eb60f33);
#
#
#             var marker_f852ef5f308a8b5b597fbcf3fb17a90d = L.marker(
#                 [18.923085025419557, -98.39557636380162],
#                 {}
#             ).addTo(map_f0cffe8ad9eeb53d991aaa603eb60f33);
#
#
#             var icon_13e4025e20a08b4629a050f30dd42baa = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;cloud&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_f852ef5f308a8b5b597fbcf3fb17a90d.setIcon(icon_13e4025e20a08b4629a050f30dd42baa);
#
#
#         var popup_3ecb0b26009eff8c2b5d7ed4cb780d24 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_a0aa4923d1b70d8082b0a216115ab9c8 = $(`&lt;div id=&quot;html_a0aa4923d1b70d8082b0a216115ab9c8&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;El clima en Atlixco es. Clima: clear sky &lt;br&gt;Temperatura: 22.18 °C&lt;/div&gt;`)[0];
#                 popup_3ecb0b26009eff8c2b5d7ed4cb780d24.setContent(html_a0aa4923d1b70d8082b0a216115ab9c8);
#
#
#
#         marker_f852ef5f308a8b5b597fbcf3fb17a90d.bindPopup(popup_3ecb0b26009eff8c2b5d7ed4cb780d24)
#         ;
#
#
#
#
#             marker_f852ef5f308a8b5b597fbcf3fb17a90d.bindTooltip(
#                 `&lt;div&gt;
#                      Atlixco
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var marker_2c7cd42cab0c391ea53d5a54b6e7f7db = L.marker(
#                 [19.295867896783285, -97.76888973800806],
#                 {}
#             ).addTo(map_f0cffe8ad9eeb53d991aaa603eb60f33);
#
#
#             var icon_4e2f76beacdfcdfba3ab5c438dd74fee = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;cloud&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_2c7cd42cab0c391ea53d5a54b6e7f7db.setIcon(icon_4e2f76beacdfcdfba3ab5c438dd74fee);
#
#
#         var popup_ea71b3061c6da56a4adbbdf2e3db8602 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_adff0395c40f74266d4a781b79c9eba0 = $(`&lt;div id=&quot;html_adff0395c40f74266d4a781b79c9eba0&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;El clima en Cuapiaxtla es. Clima: clear sky &lt;br&gt;Temperatura: 22.18 °C&lt;/div&gt;`)[0];
#                 popup_ea71b3061c6da56a4adbbdf2e3db8602.setContent(html_adff0395c40f74266d4a781b79c9eba0);
#
#
#
#         marker_2c7cd42cab0c391ea53d5a54b6e7f7db.bindPopup(popup_ea71b3061c6da56a4adbbdf2e3db8602)
#         ;
#
#
#
#
#             marker_2c7cd42cab0c391ea53d5a54b6e7f7db.bindTooltip(
#                 `&lt;div&gt;
#                      Cuapiaxtla
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var marker_9a638c10e929a88888d5262733db6ab3 = L.marker(
#                 [18.52639736316348, -97.47871399384229],
#                 {}
#             ).addTo(map_f0cffe8ad9eeb53d991aaa603eb60f33);
#
#
#             var icon_c2617915c3956ae22a1552b0ca80ed94 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;cloud&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_9a638c10e929a88888d5262733db6ab3.setIcon(icon_c2617915c3956ae22a1552b0ca80ed94);
#
#
#         var popup_f2487ef50a434f826b3b5364b25e560f = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_f070feb4fb5f227c05846b3e86d76e98 = $(`&lt;div id=&quot;html_f070feb4fb5f227c05846b3e86d76e98&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;El clima en Tehuacan es. Clima: clear sky &lt;br&gt;Temperatura: 22.18 °C&lt;/
