# %%
import json
import yaml
import requests
import folium
from pymongo import MongoClient
import logging
logging.basicConfig(filename='log.log', level=logging.DEBUG, format='%(asctime)s - %(levelname)s - %(message)s')
with open("config.yaml", "r") as f:
    config = yaml.safe_load(f)


import random

# %% [markdown]
# ## Temperatura

# %%
API_key =  config['API_key']
lat = 19.295867896783285
lon = -97.76888973800806
url = f'https://api.openweathermap.org/data/2.5/weather?lat={lat}&lon={lon}&appid={API_key}&units=metric'

# %%
response = requests.get(url)
data_weather = response.json()
data_weather
# Out:
# {'coord': {'lon': -97.7689, 'lat': 19.2959},
#  'weather': [{'id': 800,
#    'main': 'Clear',
#    'description': 'clear sky',
#    'icon': '01d'}],
#  'base': 'stations',
#  'main': {'temp': 24.66,
#   'feels_like': 23.39,
#   'temp_min': 24.66,
#   'temp_max': 24.66,
#   'pressure': 1011,
#   'humidity': 8,
#   'sea_level': 1011,
#   'grnd_level': 768},
#  'visibility': 10000,
#  'wind': {'speed': 1.45, 'deg': 85, 'gust': 1.21},
#  'clouds': {'all': 7},
#  'dt': 1708718942,
#  'sys': {'country': 'MX', 'sunrise': 1708692909, 'sunset': 1708734851},
#  'timezone': -21600,
#  'id': 3530033,
#  'name': 'Cuapiaxtla',
#  'cod': 200}

# %%
weather_description = data_weather['weather'][0]['description']
temp = data_weather['main']['temp']
text_pupup = f"Clima: {weather_description} <br>Temperatura: {temp} °C"

# %%
mapa = folium.Map(location=(lat, lon))
folium.Marker(
    location=[lat, lon],
    tooltip= 'Click Here',
    popup  = text_pupup,
    icon  =folium.Icon('cloud')
).add_to(mapa)

mapa
# Out:
# /tmp/ipykernel_199616/168895962.py:6: UserWarning: color argument of Icon should be one of: {'red', 'white', 'cadetblue', 'blue', 'darkred', 'lightgreen', 'pink', 'lightgray', 'lightred', 'gray', 'black', 'darkblue', 'green', 'darkpurple', 'darkgreen', 'orange', 'lightblue', 'beige', 'purple'}.
#   icon  =folium.Icon('cloud')
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_78e0b5e4c126a0b50617fc3ec2b83cf3 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_78e0b5e4c126a0b50617fc3ec2b83cf3&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_78e0b5e4c126a0b50617fc3ec2b83cf3 = L.map(
#                 &quot;map_78e0b5e4c126a0b50617fc3ec2b83cf3&quot;,
#                 {
#                     center: [19.295867896783285, -97.76888973800806],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 10,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_95aec2c789d7615a94af27900cb4f0f0 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 19, &quot;maxZoom&quot;: 19, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_95aec2c789d7615a94af27900cb4f0f0.addTo(map_78e0b5e4c126a0b50617fc3ec2b83cf3);
#
#
#             var marker_4dea00a2090cdc39263e3a4aa840046f = L.marker(
#                 [19.295867896783285, -97.76888973800806],
#                 {}
#             ).addTo(map_78e0b5e4c126a0b50617fc3ec2b83cf3);
#
#
#             var icon_6179e992bb7223d35f61f50450e2ab29 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;cloud&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_4dea00a2090cdc39263e3a4aa840046f.setIcon(icon_6179e992bb7223d35f61f50450e2ab29);
#
#
#         var popup_e466990c3696f4bba7cca600785b02bf = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_8631c75d41e8355a19e23cf59e759188 = $(`&lt;div id=&quot;html_8631c75d41e8355a19e23cf59e759188&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Clima: clear sky &lt;br&gt;Temperatura: 24.66 °C&lt;/div&gt;`)[0];
#                 popup_e466990c3696f4bba7cca600785b02bf.setContent(html_8631c75d41e8355a19e23cf59e759188);
#
#
#
#         marker_4dea00a2090cdc39263e3a4aa840046f.bindPopup(popup_e466990c3696f4bba7cca600785b02bf)
#         ;
#
#
#
#
#             marker_4dea00a2090cdc39263e3a4aa840046f.bindTooltip(
#                 `&lt;div&gt;
#                      Click Here
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
# &lt;/script&gt;
# &lt;/html&gt;" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
mapa
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_78e0b5e4c126a0b50617fc3ec2b83cf3 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_78e0b5e4c126a0b50617fc3ec2b83cf3&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_78e0b5e4c126a0b50617fc3ec2b83cf3 = L.map(
#                 &quot;map_78e0b5e4c126a0b50617fc3ec2b83cf3&quot;,
#                 {
#                     center: [19.295867896783285, -97.76888973800806],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 10,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_95aec2c789d7615a94af27900cb4f0f0 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 19, &quot;maxZoom&quot;: 19, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_95aec2c789d7615a94af27900cb4f0f0.addTo(map_78e0b5e4c126a0b50617fc3ec2b83cf3);
#
#
#             var marker_4dea00a2090cdc39263e3a4aa840046f = L.marker(
#                 [19.295867896783285, -97.76888973800806],
#                 {}
#             ).addTo(map_78e0b5e4c126a0b50617fc3ec2b83cf3);
#
#
#             var icon_6179e992bb7223d35f61f50450e2ab29 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;cloud&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_4dea00a2090cdc39263e3a4aa840046f.setIcon(icon_6179e992bb7223d35f61f50450e2ab29);
#
#
#         var popup_e466990c3696f4bba7cca600785b02bf = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_8631c75d41e8355a19e23cf59e759188 = $(`&lt;div id=&quot;html_8631c75d41e8355a19e23cf59e759188&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Clima: clear sky &lt;br&gt;Temperatura: 24.66 °C&lt;/div&gt;`)[0];
#                 popup_e466990c3696f4bba7cca600785b02bf.setContent(html_8631c75d41e8355a19e23cf59e759188);
#
#
#
#         marker_4dea00a2090cdc39263e3a4aa840046f.bindPopup(popup_e466990c3696f4bba7cca600785b02bf)
#         ;
#
#
#
#
#             marker_4dea00a2090cdc39263e3a4aa840046f.bindTooltip(
#                 `&lt;div&gt;
#                      Click Here
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             tile_layer_95aec2c789d7615a94af27900cb4f0f0.addTo(map_78e0b5e4c126a0b50617fc3ec2b83cf3);
#
# &lt;/script&gt;
# &lt;/html&gt;" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# ## Ejemplo con 3 ciudades

# %%
mapa_invernaderos = folium.Map(location=(lat, lon))

# %%
cities = config['cities']
for city, coord in cities.items():
    lat = coord[0]
    lon = coord[1]

    url = f'https://api.openweathermap.org/data/2.5/weather?lat={lat}&lon={lon}&appid={API_key}&units=metric'
    response = requests.get(url)
    data_weather = response.json()
    weather_description = data_weather['weather'][0]['description']
    temp = data_weather['main']['temp']
    name = data_weather['name']
    text_pupup = f"El clima en {name} es: <br> Clima: {weather_description} <br>Temperatura: {temp} °C"

    folium.Marker(
        location=[lat, lon],
        tooltip= city,
        popup  = text_pupup,
        icon  =folium.Icon(color="blue", icon="info")
    ).add_to(mapa_invernaderos)

# %%
mapa_invernaderos
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_600e6af64d09f4656419189843d18557 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_600e6af64d09f4656419189843d18557&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_600e6af64d09f4656419189843d18557 = L.map(
#                 &quot;map_600e6af64d09f4656419189843d18557&quot;,
#                 {
#                     center: [19.295867896783285, -97.76888973800806],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 10,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_bbdeb0204769c557d626502f2c89820d = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 19, &quot;maxZoom&quot;: 19, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_bbdeb0204769c557d626502f2c89820d.addTo(map_600e6af64d09f4656419189843d18557);
#
#
#             var marker_4b996b8346680dff9e29b0b609b21c06 = L.marker(
#                 [18.923085025419557, -98.39557636380162],
#                 {}
#             ).addTo(map_600e6af64d09f4656419189843d18557);
#
#
#             var icon_e5cfc26bdd54b04dbe6eab1ec248c137 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;blue&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_4b996b8346680dff9e29b0b609b21c06.setIcon(icon_e5cfc26bdd54b04dbe6eab1ec248c137);
#
#
#         var popup_af94486825f09bd4658644ab8ea3bea3 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_894fdd604205360ad6c6b6f574d8539c = $(`&lt;div id=&quot;html_894fdd604205360ad6c6b6f574d8539c&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;El clima en Atlixco es: &lt;br&gt; Clima: clear sky &lt;br&gt;Temperatura: 29.23 °C&lt;/div&gt;`)[0];
#                 popup_af94486825f09bd4658644ab8ea3bea3.setContent(html_894fdd604205360ad6c6b6f574d8539c);
#
#
#
#         marker_4b996b8346680dff9e29b0b609b21c06.bindPopup(popup_af94486825f09bd4658644ab8ea3bea3)
#         ;
#
#
#
#
#             marker_4b996b8346680dff9e29b0b609b21c06.bindTooltip(
#                 `&lt;div&gt;
#                      Atlixco
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var marker_af6f902d1f279b95034828977e6fb3bd = L.marker(
#                 [19.295867896783285, -97.76888973800806],
#                 {}
#             ).addTo(map_600e6af64d09f4656419189843d18557);
#
#
#             var icon_3912addeb4a6ae1c7a11257e16828203 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;blue&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_af6f902d1f279b95034828977e6fb3bd.setIcon(icon_3912addeb4a6ae1c7a11257e16828203);
#
#
#         var popup_55a578f390addaa48096d5aa25c31466 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_6204477ffde50080ade9da298a7f0554 = $(`&lt;div id=&quot;html_6204477ffde50080ade9da298a7f0554&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;El clima en Cuapiaxtla es: &lt;br&gt; Clima: clear sky &lt;br&gt;Temperatura: 24.66 °C&lt;/div&gt;`)[0];
#                 popup_55a578f390addaa48096d5aa25c31466.setContent(html_6204477ffde50080ade9da298a7f0554);
#
#
#
#         marker_af6f902d1f279b95034828977e6fb3bd.bindPopup(popup_55a578f390addaa48096d5aa25c31466)
#         ;
#
#
#
#
#             marker_af6f902d1f279b95034828977e6fb3bd.bindTooltip(
#                 `&lt;div&gt;
#                      Cuapiaxtla
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var marker_3b695012bc5ae04264112ef8620b729f = L.marker(
#                 [18.52639736316348, -97.47871399384229],
#                 {}
#             ).addTo(map_600e6af64d09f4656419189843d18557);
#
#
#             var icon_389177cad5d4c18d9bff65941f56ea07 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;blue&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_3b695012bc5ae04264112ef8620b729f.setIcon(icon_389177cad5d4c18d9bff65941f56ea07);
#
#
#         var popup_dec266aa108936402fae3801c6983baa = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_852356faa1c640f10f26e015c6638061 = $(`&lt;div id=&quot;html_852356faa1c640f10f26e015c6638061&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;El clima en Magdalena Cuayucatepec es: &lt;br&gt; Clima: clear sky &lt;br&

# %% [markdown]
# ### Almacenamiento en BD

# %%
def coneccionDB(mongo_uri:str,database_name:str,collection_name:str):
    "coneccion a una colecccion en base de datos"
    try:
        client = MongoClient(mongo_uri)
        db = client[database_name]
        collection = db[collection_name]
        print(f'coneccion exitosa a la coleccion: {database_name}.{collection_name}')
        return collection 
    except Exception as e:
        logging.warning(e)

# %%
API_key =  config['API_key']

_id = random.randint(1,3)
list_cities = list(config['cities'].keys())
cities = config['cities']
code_name = list_cities[_id]
city = cities[list_cities[_id]]
lat = city[0]
lon = city[1]

url = f'https://api.openweathermap.org/data/2.5/weather?lat={lat}&lon={lon}&appid={API_key}&units=metric'

response = requests.get(url)
data_weather = response.json()
data_weather['code_name']= code_name
weather_database = coneccionDB(config['connection_url'], config['db_ecoterra'], config['alerts_collection'])
weather_database.insert_one(data_weather)
# Out:
# coneccion exitosa a la coleccion: Ecoterra.weather
# InsertOneResult(ObjectId('65d8fb615128a865665d4f45'), acknowledged=True)

# %% [markdown]
# ## Forecast

# %%
# api.openweathermap.org/data/2.5/forecast?lat={lat}&lon={lon}&appid={API key}
API_key =  config['API_key']
lat = 19.295867896783285
lon = -97.76888973800806

url = f"https://api.openweathermap.org/data/2.5/weather?lat={lat}&lon={lon}&appid={API_key}&units=metric&lang='fr'"
response = requests.get(url)
data_weather = response.json()

# %% [markdown]
# ## alerts

# %%
temp = data_weather['main']['temp']
temp_min = data_weather['main']['temp_min']
humidity = data_weather['main']['humidity']
pressure = data_weather['main']['pressure']

# %%
def check_temperature(temp:float)->str:
    if config['notifications']['temp_min'] <= temp :
        if temp < config['notifications']['temp_max']:
            return 'Normal'
        else:
            return 'Temperatura elevada'
    else:
        return 'Baja temperatura'

def check_pressure(pressure:float)->str:
    if config['notifications']['pressure_min'] <= pressure :
        if pressure < config['notifications']['pressure_max']:
            return 'Normal'
        else:
            return 'Presion atmosferica elevada'
    else:
        return 'Baja presion atmosferica'

def check_humidity(humidity:float)->str:
    if config['notifications']['humidity_min'] <= humidity :
        if humidity < config['notifications']['humidity_max']:
            return 'Normal'
        else:
            return 'Humedad elevada'
    else:
        return 'Baja humedad'

# %% [markdown]
# ##  Air Pollution

# %% [markdown]
# ### Concentración de contaminantes en el aire
#
# La unidad de medida es $\mu g /m^3$
#
#
# |Qualitative name   |Index  |$SO_2 $    |$NO_2$        |$PM_{10}$       |$PM_{2.5}$   |$O_3$       |$CO$             |
# |-------------------|-------|-----------|---------------|---------------|-----------|---------------|-----------------|
# |Good 	            |1 	    |[0; 20) 	|[0; 40) 	    |[0; 20) 	    |[0; 10) 	|[0; 60) 	    |[0; 4400)        |
# |Fair 	            |2 	    |[20; 80) 	|[40; 70) 	    |[20; 50) 	    |[10; 25) 	|[60; 100) 	    |[4400; 9400)     |
# |Moderate 	        |3 	    |[80; 250) 	|[70; 150) 	    |[50; 100) 	    |[25; 50) 	|[100; 140) 	|[9400-12400)     |
# |Poor 	            |4 	    |[250; 350) |[150; 200) 	|[100; 200) 	|[50; 75) 	|[140; 180) 	|[12400; 15400)   |
# |Very Poor 	        |5 	    |⩾350 	    |⩾200 	       |⩾200 	       | ⩾75 	  |⩾180 	       |⩾15400          |
#
#
#
# fuente: [Open Weather Map](https://openweathermap.org/api/air-pollution)

# %%
AirPollutionStandars =  config['notifications']['AirPollution']

# %%
API_key =  config['API_key']
lat = 19.295867896783285
lon = -97.76888973800806
url = f'http://api.openweathermap.org/data/2.5/air_pollution?lat={lat}&lon={lon}&appid={API_key}'
response = requests.get(url)
data_weather = response.json()

# %%
def GetPollution(coord:list):
    """Coordinates coord= [lat, lon], where lat, lon is latitude and longitude in type float. \n
    Example: [19.29586, -97.768889]. \n
    Invalid formats: 18°55'22.8\" N 98°23'44.3\"W"""

    url = f'http://api.openweathermap.org/data/2.5/air_pollution?lat={lat}&lon={lon}&appid={API_key}&units=metric'
    response = requests.get(url)
    data_pollution = response.json()
    return data_pollution

# %% [markdown]
# Example

# %%
data_pollution = GetPollution(config['cities']['Atlixco'])
data_pollution
# Out:
# {'coord': {'lon': -97.7689, 'lat': 19.2959},
#  'list': [{'main': {'aqi': 3},
#    'components': {'co': 190.26,
#     'no': 0.12,
#     'no2': 0.48,
#     'o3': 101.57,
#     'so2': 1.25,
#     'pm2_5': 3.58,
#     'pm10': 4.09,
#     'nh3': 0.33},
#    'dt': 1708718946}]}

# %% [markdown]
# ### functions

# %%
so2_lvl  = data_pollution['list'][0]['components']['so2']
no2_lvl  = data_pollution['list'][0]['components']['no2']
pm10_lvl = data_pollution['list'][0]['components']['pm10']
pm2_5_lvl = data_pollution['list'][0]['components']['pm2_5']
o3_lvl   = data_pollution['list'][0]['components']['o3']
co_lvl   = data_pollution['list'][0]['components']['co']

# %%
def verification(diccionario, valor):

    for calidad, rango in diccionario.items():
        if 'min' in rango and 'max' in rango:
            if rango['min'] <= valor < rango['max']:
                return calidad
        elif 'min' in rango and valor >= rango['min']:
            return calidad

    return None

def IndexQuality(diccionario:dict, valor:float):
    Index= {'Calmed down':1, 'Soft breeze':2, 'Moderate Breeze':3, 'Strong wind': 4, 'Storm':5, None: 0}
    ver_txt = verification(diccionario, valor)
    return (ver_txt, Index[ver_txt])

# %%
def check_so2(so2_lvl:float):
    val = IndexQuality(AirPollutionStandars['so2'], so2_lvl)

    return {
        'element': 'so2',
        'value': so2_lvl,
        'status': val[0],
        'index':  val[1]
    }

def check_no2(no2_lvl:float):
    val = IndexQuality(AirPollutionStandars['no2'], no2_lvl)

    return {
        'element': 'no2',
        'value': no2_lvl,
        'status': val[0],
        'index':  val[1]
    }

def check_pm10(pm10_lvl:float):
    val = IndexQuality(AirPollutionStandars['pm10'], pm10_lvl)

    return {
        'element': 'pm10',
        'value': pm10_lvl,
        'status': val[0],
        'index':  val[1]
    }

def check_pm2_5(pm2_5_lvl:float):
    val = IndexQuality(AirPollutionStandars['pm2_5'], pm2_5_lvl)

    return {
        'element': 'pm2_5',
        'value': pm2_5_lvl,
        'status': val[0],
        'index':  val[1]
    }

def check_o3(o3_lvl:float):
    val = IndexQuality(AirPollutionStandars['o3'], o3_lvl)

    return {
        'element': 'o3',
        'value': o3_lvl,
        'status': val[0],
        'index':  val[1]
    }

def check_co(co_lvl:float):
    val = IndexQuality(AirPollutionStandars['co'], co_lvl)

    return {
        'element': 'co',
        'value': co_lvl,
        'status': val[0],
        'index':  val[1]
    }


print(check_no2(no2_lvl))
print(check_so2(so2_lvl))
print(check_pm10(pm10_lvl))
print(check_pm2_5(pm2_5_lvl))
print(check_o3(o3_lvl))
print(check_co(co_lvl))
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[21], line 62
#      52     val = IndexQuality(AirPollutionStandars['co'], co_lvl)
#      54     return {
#      55         'element': 'co',
#      56         'value': co_lvl,
#      57         'status': val[0],
#      58         'index':  val[1]
#      59     }
# ---> 62 print(check_no2(no2_lvl))
#      63 print(check_so2(so2_lvl))
#      64 print(check_pm10(pm10_lvl))
#
# Cell In[21], line 12, in check_no2(no2_lvl)
#      11 def check_no2(no2_lvl:float):
# ---> 12     val = IndexQuality(AirPollutionStandars['no2'], no2_lvl)
#      14     return {
#      15         'element': 'no2',
#      16         'value': no2_lvl,
#      17         'status': val[0],
#      18         'index':  val[1]
#      19     }
#
# Cell In[20], line 15, in IndexQuality(diccionario, valor)
#      13 Index= {'Calmed down':1, 'Soft breeze':2, 'Moderate Breeze':3, 'Strong wind': 4, 'Storm':5, None: 0}
#      14 ver_txt = verification(diccionario, valor)
# ---> 15 return (ver_txt, Index[ver_txt])
#
# KeyError: 'Good'

# %%
data_pollution
# Out:
# {'coord': {'lon': -97.7689, 'lat': 19.2959},
#  'list': [{'main': {'aqi': 3},
#    'components': {'co': 198.6,
#     'no': 0.16,
#     'no2': 0.98,
#     'o3': 120.16,
#     'so2': 5.25,
#     'pm2_5': 6.92,
#     'pm10': 7.31,
#     'nh3': 0.16},
#    'dt': 1708639653}]}
